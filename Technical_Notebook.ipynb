# %% [markdown]
# # Motivation
# I was interested to see how female participation in the labor force related to the economic status of a country. In particular this study looks at the countries shaded in orange in the map below. Before my exploration, I was torn on the idea of whether this metric would reflect that participation implies a more advanced economy, where the labor force is maximized, or if would reveal something less obvious in the end. At this time I am not sure that I have the answer to this question, although I learned some interesting trends along the way.

# %%
from IPython.display import Image 

display(Image("Images/World_Map.png"))

# %% [markdown]
# # Data
# The data used in this project was pulled from Kaggle using the Kaggle API, and can be found from the following links:
# > Women Entrepreneurship and Labor Force data from 2015 ([Kaggle](https://www.kaggle.com/babyoda/women-entrepreneurship-and-labor-force)) <br>
# > Countries of the World data from 2017 ([Kaggle](https://www.kaggle.com/fernandol/countries-of-the-world))
#
# Although the countries are not of the same year, I believe they are close enough the be used for this study. For further investigation, I encourage you to ask for updated data from the Women's Entrepreneurship Index and Global Entrepreneurship Index Report, and use those numbers for the study. At the time of this project, I am currently waiting on access to this report myself.

# %%
import pandas as pd

df = pd.read_csv("Data/data.csv")
df.head()
# Out:
#    Country Level of development European Union Membership Currency  \
# 0  Austria            Developed                    Member     Euro
# 1  Belgium            Developed                    Member     Euro
# 2  Estonia            Developed                    Member     Euro
# 3  Finland            Developed                    Member     Euro
# 4   France            Developed                    Member     Euro
#
#    Women Entrepreneurship Index  Entrepreneurship Index  Inflation rate  \
# 0                          54.9                    64.9            0.90
# 1                          63.6                    65.5            0.60
# 2                          55.4                    60.2           -0.88
# 3                          66.4                    65.7           -0.20
# 4                          68.8                    67.3            0.00
#
#    Female Labor Force Participation Rate          Region  Population  ...  \
# ...

# %%
df = pd.read_csv("Data/data_by_region.csv")
df
# Out:
#                  Region  Female Labor Force Participation Rate  \
# 0               BALTICS                              67.133333
# 1               OCEANIA                              66.800000
# 2   C.W. OF IND. STATES                              65.200000
# 3        WESTERN EUROPE                              64.320000
# 4    SUB-SAHARAN AFRICA                              60.800000
# 5        EASTERN EUROPE                              60.783333
# 6  ASIA (EX. NEAR EAST)                              60.411429
# 7   LATIN AMER. & CARIB                              57.536364
# 8       NORTHERN AFRICA                              35.930000
# 9             NEAR EAST                              21.700000
#
#    GDP ($ per capita)  Women Entrepreneurship Index  Entrepreneurship Index  \
# 0        11300.000000                     56.833333               56.433333
# 1        29000.000000                     74.800000               77.600000
# ...

# %% [markdown]
# # Correlations
# Initially I was shocked to see that there was such a weak correlation between Female Labor Force Participation and every variable in the table. Of the stronger correlations, I noticed that the Women Entrepreneurship Index was a a metric that I had not considered at first and actually had a much stronger correlation with GPD per capita. Unfortunately, I don't believe this correlation adds too much value, because the Women Entrepreneurship Index correlates highly with the Entrepreneurship Index as well.

# %%
display(Image("Images/Correlations.png"))

# %% [markdown]
# # Conclusions and Future Directions
#
# The analysis continues further, although I felt it led to a dead end and I have left that section for the additional notebook. Moving forward, I would like to gain access to the Women's Entrepreneurship Index and Global Entrepreneurship Index Report to see if I can can more current data and include a broader range of countries than the ones used above. In particular, I was interested in how the US and the UK compared to other nation since they were not included in the original dataset.
